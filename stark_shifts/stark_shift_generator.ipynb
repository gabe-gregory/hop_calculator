# %%
import numpy as np
from sys import path
path.append("Z:\\Users\\Gregory\\Ca40_multi_photon\\stark_shifts")
import stark_shift_generator as gen

# %%
g0 = gen.generator(n = 0)     # n = qudit state label in D5/2
g0.calculate_lightshifts(2)   # calculate second order shifts
g0.calculate_lightshifts(4)   # calculate fourth order shifts
g0.calculate_lightshifts(6)   # calculate sixth order shifts
g0.calculate_lightshifts(8)   # calculate eighth order shifts
# Out:
# ...
# 6th order:   0%|          | 0/64 [00:00<?, ?it/s]

# %%
g1 = gen.generator(n = 1) 
g1.calculate_lightshifts(2) 
g1.calculate_lightshifts(4)  
g1.calculate_lightshifts(6)   
g1.calculate_lightshifts(8)
# Out:
# ...
# 6th order:   0%|          | 0/64 [00:00<?, ?it/s]

# %%
g2 = gen.generator(n = 2)
g2.calculate_lightshifts(2)   
g2.calculate_lightshifts(4)  
g2.calculate_lightshifts(6)  
g2.calculate_lightshifts(8)
# Out:
# ...
# 6th order:   0%|          | 0/64 [00:00<?, ?it/s]

# %%
g3 = gen.generator(n = 3)
g3.calculate_lightshifts(2)   
g3.calculate_lightshifts(4)  
g3.calculate_lightshifts(6)  
g3.calculate_lightshifts(8)
# Out:
# ...
# 6th order:   0%|          | 0/64 [00:00<?, ?it/s]

# %%
g4 = gen.generator(n = 4)
g4.calculate_lightshifts(2)   
g4.calculate_lightshifts(4)  
g4.calculate_lightshifts(6)  
g4.calculate_lightshifts(8)
# Out:
# ...
# 6th order:   0%|          | 0/64 [00:00<?, ?it/s]

# %%
g5 = gen.generator(n = 5)
g5.calculate_lightshifts(2)   
g5.calculate_lightshifts(4)  
g5.calculate_lightshifts(6)  
g5.calculate_lightshifts(8)
# Out:
# ...
# 6th order:   0%|          | 0/64 [00:00<?, ?it/s]

# %%
path = "\\Users\\Gregory\\Ca40_multi_photon\\stark_shifts\\"

np.save(path + str(g0.n) + "2.npy", g0.E2) 
np.save(path + str(g0.n) + "4.npy", g0.E4)
np.save(path + str(g0.n) + "6.npy", g0.E6)
np.save(path + str(g0.n) + "8.npy", g0.E8)

np.save(path + str(g1.n) + "2.npy", g1.E2) 
np.save(path + str(g1.n) + "4.npy", g1.E4)
np.save(path + str(g1.n) + "6.npy", g1.E6)
np.save(path + str(g1.n) + "8.npy", g1.E8)

np.save(path + str(g2.n) + "2.npy", g2.E2) 
np.save(path + str(g2.n) + "4.npy", g2.E4)
np.save(path + str(g2.n) + "6.npy", g2.E6)
np.save(path + str(g2.n) + "8.npy", g2.E8)

np.save(path + str(g3.n) + "2.npy", g3.E2) 
np.save(path + str(g3.n) + "4.npy", g3.E4)
np.save(path + str(g3.n) + "6.npy", g3.E6)
np.save(path + str(g3.n) + "8.npy", g3.E8)

np.save(path + str(g4.n) + "2.npy", g4.E2) 
np.save(path + str(g4.n) + "4.npy", g4.E4)
np.save(path + str(g4.n) + "6.npy", g4.E6)
np.save(path + str(g4.n) + "8.npy", g4.E8)

np.save(path + str(g5.n) + "2.npy", g5.E2) 
np.save(path + str(g5.n) + "4.npy", g5.E4)
np.save(path + str(g5.n) + "6.npy", g5.E6)
np.save(path + str(g5.n) + "8.npy", g5.E8)
