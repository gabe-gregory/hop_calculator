# %%
import numpy as np
from sys import path
path.append("Z:\\Users\\Gregory\\Ca40_multi_photon\\rabi_frequencies")
import rabi_freq_generator as gen
import sympy as sp

# %% [markdown]
# ## No F states, No counter rotating terms, pure polarizations

# %%
n = 0   # initial state in D5/2
f = 3   # final state in D5/2
res = 2 # 2*res = number of photon resonance set to

gen03_4 = gen.generator(n = n, f = f, res = res, polarizations = 'pure', terms = 'basic')
gen03_4.calc_fourth_order()

# %%
n = 0 
f = 3
res = 2

gen03_6 = gen.generator(n = n, f = f, res = res, polarizations = 'pure', terms = 'basic')
gen03_6.calc_sixth_order()
# Out:
# 6th order:   0%|          | 0/64 [00:00<?, ?it/s]

# %%
n = 0   # initial state in D5/2
f = 4   # final state in D5/2
res = 3 # 2*res = number of photon resonance set to

gen04_6 = gen.generator(n = n, f = f, res = res, polarizations = 'pure', terms = 'basic')
gen04_6.calc_sixth_order()
# Out:
# 6th order:   0%|          | 0/64 [00:00<?, ?it/s]

# %%
np.save("Z:\\Users\\Gregory\\Ca40_multi_photon\\rabi_frequencies\\03_4_pure.npy", gen03_4.terms)
np.save("Z:\\Users\\Gregory\\Ca40_multi_photon\\rabi_frequencies\\03_6_pure.npy", gen03_6.terms)
np.save("Z:\\Users\\Gregory\\Ca40_multi_photon\\rabi_frequencies\\04_6_pure.npy", gen04_6.terms)

# %%
gen03_4.terms
# Out:
# array([Ω06r*Ω16b*Ω17r*Ω37b/(8*Δ**2*(ω01 - ωr)),
#        Ω06r*Ω26b*Ω28r*Ω38b/(8*Δ**2*(ω01 + ω12 - ωr))], dtype=object)

# %%
gen04_6.terms
# Out:
# array([-Ω06b*Ω06r**2*Ω26b*Ω28r*Ω48b/(32*Δ**3*ωr*(ω01 + ω12 - 2*ωr)),
#        Ω06r*Ω16b*Ω17r*Ω27b*Ω28r*Ω48b/(32*Δ**3*(ω01 - ωr)*(ω01 + ω12 - 2*ωr)),
#        Ω06r*Ω26b*Ω28b*Ω28r**2*Ω48b/(32*Δ**3*(ω01 + ω12 - 2*ωr)*(ω01 + ω12 - ωr)),
#        Ω06r*Ω16b*Ω17r*Ω37b*Ω39r*Ω49b/(32*Δ**3*(ω01 - ωr)*(ω01 + ω12 + ω23 - 2*ωr)),
#        Ω06r*Ω26b*Ω28r*Ω38b*Ω39r*Ω49b/(32*Δ**3*(ω01 + ω12 - ωr)*(ω01 + ω12 + ω23 - 2*ωr))],
#       dtype=object)
