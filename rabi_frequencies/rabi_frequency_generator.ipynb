# %%
import numpy as np
from sys import path
path.append("Z:\\Users\\Gregory\\Ca40_multi_photon\\rabi_frequencies")
import rabi_freq_generator as gen
import sympy as sp

# %% [markdown]
# ## No F states, No counter rotating terms, full polarizations

# %%
n = 0   # initial state in D5/2
f = 3   # final state in D5/2
res = 2 # 2*res = number of photon resonance set to

gen03_4 = gen.generator(n = n, f = f, res = res, polarizations = 'impure', terms = 'basic')
gen03_4.calc_fourth_order()

# %%
n = 0 
f = 3
res = 2

gen03_6 = gen.generator(n = n, f = f, res = res, polarizations = 'impure', terms = 'basic')
gen03_6.calc_sixth_order()
# Out:
# 6th order:   0%|          | 0/64 [00:00<?, ?it/s]

# %%
len(gen03_6.terms)
# Out:
# 104

# %%
n = 0   # initial state in D5/2
f = 4   # final state in D5/2
res = 3 # 2*res = number of photon resonance set to

gen04_6 = gen.generator(n = n, f = f, res = res, polarizations = 'impure', terms = 'basic')
gen04_6.calc_sixth_order()
# Out:
# 6th order:   0%|          | 0/64 [00:00<?, ?it/s]

# %%
np.save("Z:\\Users\\Gregory\\Ca40_multi_photon\\rabi_frequencies\\03_4.npy", gen03_4.terms)
np.save("Z:\\Users\\Gregory\\Ca40_multi_photon\\rabi_frequencies\\03_6.npy", gen03_6.terms)
np.save("Z:\\Users\\Gregory\\Ca40_multi_photon\\rabi_frequencies\\04_6.npy", gen04_6.terms)

# %%
n = 1   # initial state in D5/2
f = 4   # final state in D5/2
res = 2 # 2*res = number of photon resonance set to

gen14_4 = gen.generator(n = n, f = f, res = res, polarizations = 'impure', terms = 'basic')
gen14_4.calc_fourth_order()

# %%
gen14_4.terms
# Out:
# array([Ω16r*Ω26b*Ω28r*Ω48b/(8*Δ**2*(ω01 + ω12 - ωr)),
#        Ω17r*Ω27b*Ω28r*Ω48b/(8*Δ**2*(ω01 + ω12 - ωr)),
#        Ω17r*Ω37b*Ω38r*Ω48b/(8*Δ**2*(ω01 + ω12 + ω23 - ωr)),
#        Ω17r*Ω37b*Ω39r*Ω49b/(8*Δ**2*(ω01 + ω12 + ω23 - ωr))], dtype=object)

# %%
n = 2   # initial state in D5/2
f = 5   # final state in D5/2
res = 2 # 2*res = number of photon resonance set to

gen25_4 = gen.generator(n = n, f = f, res = res, polarizations = 'impure', terms = 'basic')
gen25_4.calc_fourth_order()

# %%
gen25_4.terms
# Out:
# array([Ω27r*Ω37b*Ω39r*Ω59b/(8*Δ**2*(ω01 + ω12 + ω23 - ωr)),
#        Ω28r*Ω38b*Ω39r*Ω59b/(8*Δ**2*(ω01 + ω12 + ω23 - ωr)),
#        Ω28r*Ω48b*Ω49r*Ω59b/(8*Δ**2*(ω01 + ω12 + ω23 + ω34 - ωr))],
#       dtype=object)

# %%
np.save("Z:\\Users\\Gregory\\hop_calculator\\rabi_frequencies\\14_4.npy", gen14_4.terms)
np.save("Z:\\Users\\Gregory\\hop_calculator\\rabi_frequencies\\25_4.npy", gen25_4.terms)

# %%
n = 1   # initial state in D5/2
f = 5   # final state in D5/2
res = 3 # 2*res = number of photon resonance set to

gen15_6 = gen.generator(n = n, f = f, res = res, polarizations = 'impure', terms = 'basic')
gen15_6.calc_sixth_order()
# Out:
# 6th order:   0%|          | 0/64 [00:00<?, ?it/s]

# %%
n = 0   # initial state in D5/2
f = 5   # final state in D5/2
res = 3 # 2*res = number of photon resonance set to

gen05_6 = gen.generator(n = n, f = f, res = res, polarizations = 'impure', terms = 'basic')
gen05_6.calc_sixth_order()
# Out:
# 6th order:   0%|          | 0/64 [00:00<?, ?it/s]

# %%
np.save("Z:\\Users\\Gregory\\hop_calculator\\rabi_frequencies\\15_6.npy", gen15_6.terms)
np.save("Z:\\Users\\Gregory\\hop_calculator\\rabi_frequencies\\05_6.npy", gen05_6.terms)
