# %%
import sys
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
sys.path.insert(0, r'Z:\Users\Gregory\Ca40_multi_photon')
sys.path.insert(0, r'Z:\Users\Gregory\Ca40_multi_photon\raman_simulation')
import useful_funcs
import simulation as s

cb_d = (106/255, 139/255,239/255)
cb_l = (158/255, 190/255,255/255)
cr_d = (214/255, 82/255,68/255)
cr_l = (244/255, 152/255,122/255)

# %%
tpi_bank4 = np.logspace(-5, -3, 10)
P_bank4 = 3.4*1e-6/tpi_bank4

# %%
sim4 = s.sim()
sim4.transition = '+5/2<->-1/2'
sim4.get_f()

# %%
sim4.power_scaling(P_bank4)
sim4.analytics(P_bank4, sim_resonance = sim4.w_num_bank)
# Out:
# ...
# spectroscopy, Pb = 3.4 mW:   0%|          | 0/40 [00:00<?, ?it/s]

# %%
tpi_bank6 = np.logspace(-4, -2.7, 10)
P_bank6 = 3.5*1e-4/tpi_bank6**(2/3)

# %%
sim6 = s.sim()
sim6.transition = '+5/2<->-3/2'
sim6.ls_order = 8
sim6.get_f()

# %%
sim6.power_scaling(P_bank6)
# Out:
# ...
# spectroscopy, Pb = 22.08 mW:   0%|          | 0/40 [00:00<?, ?it/s]

# %%
sim6.ls_order = 2
sim6.analytics(P_bank6, sim_resonance = sim6.w_num_bank)

# %%
with plt.style.context(['science', 'no-latex']):
    plt.figure(dpi = 500, figsize = (3,2.5))

    plt.errorbar(np.pi/(sim4.Ω_num_bank*1e-6),abs(1-(sim4.Ω_num_bank)/(abs(sim4.Ω03_4) - abs(sim4.Ω03_6))), 1e-12*sim4.δΩ_num_bank/(abs(sim4.Ω03_4) - abs(sim4.Ω03_6)),
         marker = '.' , ls = 'none', ecolor = cb_d, markeredgecolor = cb_d, markeredgewidth = .4, 
         markersize=8, capsize=1, elinewidth = .5,markerfacecolor=cb_l, alpha = 1, label='4-photon')
    plt.errorbar(np.pi/(sim6.Ω_num_bank*1e-6),abs(1-(sim6.Ω_num_bank)/abs(sim6.Ω04_6)), 1e-12*sim6.δΩ_num_bank/(abs(sim6.Ω04_6)),
         marker = 's' , ls = 'none', ecolor = cr_d, markeredgecolor = cr_d, markeredgewidth = .4, 
         markersize=4, capsize=1, elinewidth = .5,markerfacecolor=cr_l, alpha = 1, label='6-photon')

    plt.xlabel(r'$\pi$-time ($\mu$s)')
    plt.xscale('log')
    plt.yscale('log')
    plt.legend()
    plt.ylabel('1 - numerics / analytics')
    # plt.plot(x_fit*1e6,y6_fit, color = cr_l)
    # plt.plot(x_fit*1e6,y4_fit, color = cb_l)
    # plt.plot(x_fit*1e6,y6_fit2, color = cr_l)
    # plt.ylim(5e-3, .4)
    # plt.xlim(10, 3e3)
    plt.show()

# %%
sim6.spot_check(9)
